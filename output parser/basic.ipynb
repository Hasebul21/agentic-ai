# %%
from langchain_core.prompts import PromptTemplate
from langchain_groq import ChatGroq
from dotenv import load_dotenv
from langchain_core.output_parsers import JsonOutputParser, StrOutputParser
import json

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatGroq(
    model="qwen/qwen3-32b",
    reasoning_format = "hidden"
)

parser = JsonOutputParser()
string_parser = StrOutputParser()

# %%
template = PromptTemplate(
    template='Tell me about that topic {topic} \n {format_instructions}',
    input_variables = ['topic'],
    partial_variables = {'format_instructions' : parser.get_format_instructions()},
    validate_template = True
)

# %%
print(template.invoke({'topic': 'Triangle'}))

chain = template | llm | parser

response = chain.invoke({'topic': 'Triangle'})
print(parser.get_format_instructions())
print(json.dumps(response, indent=2, ensure_ascii=False))
# Out:
# text='Tell me about that topic Triangle \n Return a JSON object.'
# Return a JSON object.
# {
#   "topic": "Triangle",
#   "description": [
#     {
#       "section": "Basic Properties",
#       "content": "A triangle is a polygon with three edges (sides) and three vertices (corners). The sum of its interior angles is always 180° in Euclidean geometry."
#     },
#     {
#       "section": "Types of Triangles",
#       "content": "Triangles are classified by sides (equilateral: all sides equal, isosceles: two sides equal, scalene: no sides equal) or angles (acute: all angles <90°, right: one 90° angle, obtuse: one angle >90°)."
#     },
#     {
#       "section": "Congruence and Similarity",
#       "content": "Triangles are congruent (identical in shape and size) if they meet SSS, SAS, ASA, or AAS criteria. Similar triangles (same shape, different size) follow AA, SSS, or SAS similarity criteria."
#     },
#     {
#       "section": "Area Calculation",
#       "content": "Area is calculated as (base × height)/2. For right-angled triangles, it’s (product of legs)/2. Heron’s formula: area = √[s(s-a)(s-b)(s-c)] where s = (a+b+c)/2."
#     },
#     {
#       "section": "Key Theorems",
#       "content": "Triangle inequality theorem: sum of any two sides > third side. Pythagorean theorem: in right-angled triangles, a² + b² = c² (c = hypotenuse)."
#     },
#     {
#       "section": "Applications",
#       "content": "Used in architecture (truss structures), navigation (triangulation), physics (vector analysis), and computer graphics (3D modeling)."
#     }
#   ]
# }
